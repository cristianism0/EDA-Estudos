# %% [markdown]
# # Exploratory Data Analysis for a Eathquake Dataset

# %% [markdown]
# ### First Step: Understand the Data and Running Basic Libraries

# %%
# Often we will use a "BASIC ML KIT", this one:
import pandas as pd                  # for CSV vizualization
import matplotlib.pyplot as plt      # for Graphics
import seaborn as sns                # for _better_ Graphics
